# %% [markdown]
# # Custom Energy Function

# %%
import chilife as xl
import pickle
import matplotlib.pyplot as plt
import numpy as np

from chilife import EnergyFunc

plt.style.use('chiLife')

# %%
with open('R1_Data.pkl', 'rb') as f:
    data = pickle.load(f)
omp = xl.fetch('1omp')
anf = xl.fetch('1anf')

# %%
class CustomEnergyFunc(xl.ljEnergyFunc):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.ljFunc = super().__call__
        self.sa_weight = 0.078 
        self.func_forgive = 0.94
    
    def __call__(self, rotens):
        ljE = self.ljFunc(rotens, forgive=self.func_forgive)
        SASA = rotens.get_sasa()
        return ljE - self.sa_weight * SASA
         
        

my_sfxn = CustomEnergyFunc()

SL1 = xl.SpinLabel('R1M', 41, anf, energy_func=my_sfxn)
SL2 = xl.SpinLabel('R1M', 238, anf, energy_func=my_sfxn)
SL2 = xl.SpinLabel('R1M', 345, anf, energy_func=my_sfxn)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 17
#      11         return ljE - self.sa_weight * SASA
#      15 my_sfxn = CustomEnergyFunc()
# ---> 17 SL1 = xl.SpinLabel('R1M', 41, anf, energy_func=my_sfxn)
#      18 SL2 = xl.SpinLabel('R1M', 238, anf, energy_func=my_sfxn)
#      19 SL2 = xl.SpinLabel('R1M', 345, anf, energy_func=my_sfxn)
#
# File E:\07)Programming\Python\chiLife\src\chilife\SpinLabel.py:33, in SpinLabel.__init__(self, label, site, protein, chain, rotlib, **kwargs)
#      30 if not kwargs.get('minimize', False):
#      31     kwargs.setdefault("eval_clash", True)
# ---> 33 super().__init__(label, site, protein=protein, chain=chain, rotlib=rotlib, **kwargs)
#      35 self.label = label
#      37 # Parse spin delocalization information
#
# File E:\07)Programming\Python\chiLife\src\chilife\RotamerEnsemble.py:184, in RotamerEnsemble.__init__(self, res, site, protein, chain, rotlib, **kwargs)
#     181 if self.chain not in ('A', None):
#     182     self.name += f"_{self.chain}"
# --> 184 self.update(no_lib=True)
#     186 # Store atom information as atom objects
#     187 self.atoms = [
#     188     FreeAtom(name, atype, idx, self.res, self.site, coord)
#     189     for idx, (coord, atype, name) in enumerate(
#     190         zip(self._coords[0], self.atom_types, self.atom_names)
#     191     )
#     192 ]
#
# File E:\07)Programming\Python\chiLife\src\chilife\RotamerEnsemble.py:428, in RotamerEnsemble.update(self, no_lib)
#     425     self.weights = self._weights.copy()
#     427 if self.protein is not None:
# --> 428     self.protein_setup()
#     429 else:
#     430     self.ICs_to_site(self.origin, self.mx)
#
# File E:\07)Programming\Python\chiLife\src\chilife\RotamerEnsemble.py:461, in RotamerEnsemble.protein_setup(self)
#     457     raise RuntimeError('Both `minimize` and `eval_clash` options have been selected, but they are incompatible.'
#     458                        'Please select only one. Also note that minimize performs its own clash evaluations so '
#     459                        'eval_clash is not necessary.')
#     460 elif self.eval_clash:
# --> 461     self.evaluate()
#     463 elif self._minimize:
#     464     self.minimize()
#
# File E:\07)Programming\Python\chiLife\src\chilife\RotamerEnsemble.py:989, in RotamerEnsemble.evaluate(self)
#     986 """Place rotamer ensemble on protein site and recalculate rotamer weights."""
#     988 # Calculate external energies
# --> 989 energies = self.energy_func(self)
#     991 # Calculate total weights (combining internal and external)
#     992 self.weights, self.partition = scoring.reweight_rotamers(energies, self.temp, self.weights)
#
# Cell In[5], line 9, in CustomEnergyFunc.__call__(self, rotens)
#       8 def __call__(self, rotens):
# ----> 9     ljE = self.ljFunc(rotens, forgive=self.func_forgive)
#      10     SASA = rotens.get_sasa()
#      11     return ljE - self.sa_weight * SASA
#
# File E:\07)Programming\Python\chiLife\src\chilife\scoring.py:510, in ljEnergyFunc.__call__(self, system, internal, **kwargs)
#     508 tkwargs.update(kwargs)
#     509 r, rmin, eps, shape = self._get_functional_input(system, internal)
# --> 510 E = self.functional(r, rmin, eps, **tkwargs)
#     512 E = E.reshape(*shape, -1)
#     513 if isinstance(system, (re.RotamerEnsemble, dre.dRotamerEnsemble)):
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:1187, in _pydevd_bundle.pydevd_cython_win32_312_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:627, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:937, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:928, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:585, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.do_wait_suspend()
#
# File C:\Program Files\JetBrains\PyCharm 2023.1\plugins\python\helpers\pydev\pydevd.py:1185, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1182         from_this_thread.append(frame_id)
#    1184 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1185     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File C:\Program Files\JetBrains\PyCharm 2023.1\plugins\python\helpers\pydev\pydevd.py:1200, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1197             self._call_mpl_hook()
#    1199         self.process_internal_commands()
# -> 1200         time.sleep(0.01)
#    1202 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1204 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
labels = ('Custom Score Function', 'Default Score Function')
fig, axs = plt.subplots(2)
for ax, cstruct in zip(axs, (("41", "238", 'Holo'), ("238", "345", 'Holo'))):
    exp = data[cstruct]
    ax.plot(exp.r, exp.P, color='k', label='Exp')
    ax.fill_between(exp.r, *exp.P95, color='k', alpha=0.5, label='95% CI')
    
    for i, efunc in enumerate((my_sfxn, xl.ljEnergyFunc(xl.get_lj_scwrl))):
        SL1 = xl.SpinLabel('R1M', cstruct[0], anf, energy_func = efunc)
        SL2 = xl.SpinLabel('R1M', cstruct[1], anf, energy_func = efunc)
        dd = xl.distance_distribution(SL1, SL2, exp.r)
        ax.plot(exp.r, dd, label=labels[i])
        
    ax.set_yticks([])
    ax.set_xlim(15, 65)
    for spine in ['left', 'top', 'right']:
        ax.spines[spine].set_visible(False)
    
axs[0].set_title('MBP D41R1 S238R1 Holo')
axs[1].set_title('MBP S238R1 T345R1 Holo')
        
axs[0].legend(frameon=False)
axs[1].set_xlabel(r'distance ($\rm\AA$)')

plt.tight_layout()
plt.show()
